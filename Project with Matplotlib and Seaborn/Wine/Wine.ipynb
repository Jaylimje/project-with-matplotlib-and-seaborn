# %% [markdown]
# # Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 2. Import the dataset from this address.

# %%
pd.read_csv('wine.csv', sep='\,')
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_14372\3966750328.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv('wine.csv', sep='\,')
#      "1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    "1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    "1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    "1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    "1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    "1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..   ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  "3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  "3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  "3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  "3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  "3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065"
# 0    3.40  1050"
# 1    3.17  1185"
# 2    3.45  1480"
# 3    2.93   735"
# 4    2.85  1450"
# ..    ...    ...
# 172  1.74   740"
# 173  1.56   750"
# 174  1.56   835"
# 175  1.62   840"
# 176  1.60   560"
#
# [177 rows x 14 columns]

# %% [markdown]
# # Step 3. Assign it to a variable called wine

# %%
wine = pd.read_csv('wine.csv', sep='\,')
wine.head()
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_14372\2714806143.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   wine = pd.read_csv('wine.csv', sep='\,')
#    "1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  "1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  "1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  "1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  "1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  "1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065"
# 0  1050"
# 1  1185"
# 2  1480"
# 3   735"
# 4  1450"

# %% [markdown]
# # Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine.shape
# Out:
# (177, 14)

# %%
wine = wine.drop(wine.columns[[0,3,6,8,10,12,13]], axis = 1)
wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  1.04
# 0  13.20  1.78  11.2  100  2.76  1.28  1.05
# 1  13.16  2.36  18.6  101  3.24  2.81  1.03
# 2  14.37  1.95  16.8  113  3.49  2.18  0.86
# 3  13.24  2.59  21.0  118  2.69  1.82  1.04
# 4  14.20  1.76  15.2  112  3.39  1.97  1.05

# %% [markdown]
# # Step 5. Assign the columns as below: The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns = ['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium', 'flavanoids', 'proanthocyanins', 'hue']
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# # Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.iloc[0:3, 0] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2        100        2.76
# 1      NaN        2.36               18.6        101        3.24
# 2      NaN        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# # Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.iloc[2:4, 3] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8        NaN        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# # Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine.alcohol.fillna(10, inplace = True)
wine.magnesium.fillna(100, inplace = True)
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00        1.78               11.2      100.0        2.76
# 1    10.00        2.36               18.6      101.0        3.24
# 2    10.00        1.95               16.8      100.0        3.49
# 3    13.24        2.59               21.0      100.0        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# # Step 9. Count the number of missing values

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# # Step 10. Create an array of 10 random numbers up until 10

# %%
random = np.random.randint(10, size = 10)
random
# Out:
# array([2, 1, 4, 1, 8, 3, 2, 8, 0, 6])

# %% [markdown]
# # Step 11. Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine.alcohol[random] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8      100.0        3.49
# 3      NaN        2.59               21.0      100.0        2.69
# 4      NaN        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# # Step 12. How many missing values do we have?

# %%
wine.isnull().sum()
# Out:
# alcohol              7
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# # Step 13. Delete the rows that contain missing values

# %%
wine = wine.dropna(axis = 0, how = 'any')
wine.head()
# Out:
#     alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 5     14.39        1.87               14.6       96.0        2.52
# 7     14.83        1.64               14.0       97.0        2.98
# 9     14.10        2.16               18.0      105.0        3.32
# 10    14.12        1.48               16.8       95.0        2.43
# 11    13.75        1.73               16.0       89.0        2.76
#
#     proanthocyanins   hue
# 5              1.98  1.02
# 7              1.98  1.08
# 9              2.38  1.25
# 10             1.57  1.17
# 11             1.81  1.15

# %% [markdown]
# # Step 14. Print only the non-null values in alcohol

# %%
a = wine.alcohol.notnull()
a
# Out:
# 5      True
# 7      True
# 9      True
# 10     True
# 11     True
#        ...
# 172    True
# 173    True
# 174    True
# 175    True
# 176    True
# Name: alcohol, Length: 170, dtype: bool

# %%
wine.alcohol[a]
# Out:
# 5      14.39
# 7      14.83
# 9      14.10
# 10     14.12
# 11     13.75
#        ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: alcohol, Length: 170, dtype: float64

# %% [markdown]
# # Step 15. Reset the index, so it starts with 0 againBONUS: Create your own question and answer it.

# %%
wine = wine.reset_index(drop = True)
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      14.39        1.87               14.6       96.0        2.52
# 1      14.83        1.64               14.0       97.0        2.98
# 2      14.10        2.16               18.0      105.0        3.32
# 3      14.12        1.48               16.8       95.0        2.43
# 4      13.75        1.73               16.0       89.0        2.76
# ..       ...         ...                ...        ...         ...
# 165    13.71        5.65               20.5       95.0        0.61
# 166    13.40        3.91               23.0      102.0        0.75
# 167    13.27        4.28               20.0      120.0        0.69
# 168    13.17        2.59               20.0      120.0        0.68
# 169    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.98  1.02
# 1               1.98  1.08
# 2               2.38  1.25
# 3               1.57  1.17
# 4               1.81  1.15
# ..               ...   ...
# 165             1.06  0.64
# 166             1.41  0.70
# 167             1.35  0.59
# 168             1.46  0.60
# 169             1.35  0.61
#
# [170 rows x 7 columns]
